# %% [markdown]
# # kMeans clustering
#
# In this lab you will separate iris species as well as you can using
# k-means clustering.  Proceed as follows:
#
# 1. load the iris data
# 2. select two features.  Plot the data, depict the (true) species as
# different colors.
# 3. perform k-means clustering.  Try different $k$-s (2,3,4,5 or so).
# Disregarding the true species, think which one gives you the best
# clustering.
# 4. repeat the exercise with different pairs of features.
# 5. pick your "favorite 2d model": the model that seems visually the
# most convincing.
# 6. Now do kmeans on all 4 features.  Compare the results with the true
# species and compute accuracy.  Note: the k-means detected cluster id-s
# may be different from the original id-s.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import sklearn.datasets as ds
from sklearn.cluster import KMeans

# %% [markdown]
# ## 1. load the data

# %%
iris = ds.load_iris()
x = iris['data'][:,:2]
# select 1st and 2nd feature
y = iris['target']

# %% [markdown]
# ## 2. plot data

# %%
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)

# %% [markdown]
# ## 3. kmeans

# %%
km = KMeans(3)
# find 3 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
km = KMeans(4)
# find 3 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %% [markdown]
# ## 4. try other covariates

# %%
x = iris['data'][:,2:4]
# select 3rd and 4th feature
y = iris['target']
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)

# %%
km = KMeans(3)
# find 3 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
km = KMeans(5)
# find 5 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
x = iris['data'][:,1:3]
# select 2nd and 3rd feature
y = iris['target']
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)

# %%
km = KMeans(3)
# find 3 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
km = KMeans(2)
# find 2 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
km = KMeans(4)
# find 4 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %% [markdown]
# ## 5. Pick the best

# %%
# It cannot be determined which is the best- it is unsupervised.

# %% [markdown]
# ## 6. all 4 features

# %%
x = iris['data']
# print(x)
# select all features
y = iris['target']
plt.jet()
plt.figure(figsize=(10,10))
sd = 0.02
plt.scatter(x[:,0] + np.random.normal(0, sd, 150), x[:,1] + np.random.normal(0, sd, 150), c=y, s=100)

# %%
km = KMeans(3)
# find 3 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
km = KMeans(2)
# find 2 clusters
hatY = km.fit(x).labels_
mu = km.cluster_centers_
plt.figure(figsize=(10,10))
plt.scatter(x[:,0], x[:,1], c=hatY, alpha=0.3)
plt.scatter(mu[:,0], mu[:,1], c=np.unique(hatY), s=100)

# %%
pd.crosstab(hatY,y)
# Out:
# col_0   0   1   2
# row_0
# 0       0  48  14
# 1      50   0   0
# 2       0   2  36

# %%
#There is only one group under column 0 therefore it is most accurate

# %%
pd.crosstab(hatY,y)
# Out:
# col_0   0   1   2
# row_0
# 0       0  47  50
# 1      50   3   0

# %%
#Columns 0 and 2 have one value each, therefore it is accurate
